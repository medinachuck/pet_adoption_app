# %%
import pandas as pd
import numpy as np

# %%
# Pets Train CSV import
train_data = ('petfinder_adoption_data/train.csv')
df_train_data = pd.read_csv(train_data)
df_train_data.head()
# Out:
#    Type         Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 0     2       Nibble    3     299       0       1       1       7       0
# 1     2  No Name Yet    1     265       0       1       1       2       0
# 2     1       Brisco    1     307       0       1       2       7       0
# 3     1         Miko    4     307       0       2       1       2       0
# 4     1       Hunter    1     307       0       1       1       0       0
#
#    MaturitySize  ...  Health  Quantity  Fee  State  \
# 0             1  ...       1         1  100  41326
# 1             2  ...       1         1    0  41401
# 2             2  ...       1         1    0  41326
# 3             2  ...       1         1  150  41401
# 4             2  ...       1         1    0  41326
#
#                           RescuerID  VideoAmt  \
# 0  8480853f516546f6cf33aa88cd76c379         0
# 1  3082c7125d8fb66f7dd4bff4192c8b14         0
# 2  fa90fa5b1ee11c86938398b60abc32cb         0
# ...

# %%
print(df_train_data.count())
print(df_train_data.isnull().values.any())
# Out:
# Type             14993
# Name             13736
# Age              14993
# Breed1           14993
# Breed2           14993
# Gender           14993
# Color1           14993
# Color2           14993
# Color3           14993
# MaturitySize     14993
# FurLength        14993
# Vaccinated       14993
# Dewormed         14993
# Sterilized       14993
# Health           14993
# Quantity         14993
# Fee              14993
# State            14993
# RescuerID        14993
# VideoAmt         14993
# Description      14981
# PetID            14993
# PhotoAmt         14993
# AdoptionSpeed    14993
# dtype: int64
# True

# %%
df_train_data.columns
# Out:
# Index(['Type', 'Name', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1', 'Color2',
#        'Color3', 'MaturitySize', 'FurLength', 'Vaccinated', 'Dewormed',
#        'Sterilized', 'Health', 'Quantity', 'Fee', 'State', 'RescuerID',
#        'VideoAmt', 'Description', 'PetID', 'PhotoAmt', 'AdoptionSpeed'],
#       dtype='object')

# %%
df_train_data.dtypes
# Out:
# Type               int64
# Name              object
# Age                int64
# Breed1             int64
# Breed2             int64
# Gender             int64
# Color1             int64
# Color2             int64
# Color3             int64
# MaturitySize       int64
# FurLength          int64
# Vaccinated         int64
# Dewormed           int64
# Sterilized         int64
# Health             int64
# Quantity           int64
# Fee                int64
# State              int64
# RescuerID         object
# VideoAmt           int64
# Description       object
# PetID             object
# PhotoAmt         float64
# AdoptionSpeed      int64
# dtype: object

# %%
## Rename columns for Merger
df_train_data = df_train_data.rename(columns={"Breed1": "BreedID", "Breed2": "BreedID2", "Color1": "ColorID", "Color2": "ColorID2", "Color3": "ColorID3", "State":"StateID"})

# %%
df_train_data
# Out:
#        Type            Name  Age  BreedID  BreedID2  Gender  ColorID  \
# 0         2          Nibble    3      299         0       1        1
# 1         2     No Name Yet    1      265         0       1        1
# 2         1          Brisco    1      307         0       1        2
# 3         1            Miko    4      307         0       2        1
# 4         1          Hunter    1      307         0       1        1
# ...     ...             ...  ...      ...       ...     ...      ...
# 14988     2             NaN    2      266         0       3        1
# 14989     2  Serato & Eddie   60      265       264       3        1
# 14990     2         Monkies    2      265       266       3        5
# 14991     2         Ms Daym    9      266         0       2        4
# 14992     1            Fili    1      307       307       1        2
#
#        ColorID2  ColorID3  MaturitySize  ...  Health  Quantity  Fee  StateID  \
# ...

# %%
# Pets Breed Labels CSV import
breed_labels = ('petfinder_adoption_data/breed_labels.csv')
df_breed_labels = pd.read_csv(breed_labels)
df_breed_labels.head()
# Out:
#    BreedID  Type         BreedName
# 0        1     1     Affenpinscher
# 1        2     1      Afghan Hound
# 2        3     1  Airedale Terrier
# 3        4     1            Akbash
# 4        5     1             Akita

# %%
print(df_breed_labels.count())
print(df_breed_labels.isnull().values.any())
# Out:
# BreedID      307
# Type         307
# BreedName    307
# dtype: int64
# False

# %%
df_breed_labels.columns
# Out:
# Index(['BreedID', 'Type', 'BreedName'], dtype='object')

# %%
df_breed_labels['BreedID'] = df_breed_labels['BreedID'].astype(int)

# %%
df_breed_labels.dtypes
# Out:
# BreedID       int64
# Type          int64
# BreedName    object
# dtype: object

# %%
# Pets Color Labels CSV import
color_labels = ('petfinder_adoption_data/color_labels.csv')
df_color_labels = pd.read_csv(color_labels)
df_color_labels.head()
# Out:
#    ColorID ColorName
# 0        1     Black
# 1        2     Brown
# 2        3    Golden
# 3        4    Yellow
# 4        5     Cream

# %%
print(df_color_labels.count())
print(df_color_labels.isnull().values.any())
# Out:
# ColorID      7
# ColorName    7
# dtype: int64
# False

# %%
df_color_labels.columns
# Out:
# Index(['ColorID', 'ColorName'], dtype='object')

# %%
# Pets State Labels CSV import
state_labels = ('petfinder_adoption_data/state_labels.csv')
df_state_labels = pd.read_csv(state_labels)
df_state_labels.head()
# Out:
#    StateID     StateName
# 0    41336         Johor
# 1    41325         Kedah
# 2    41367      Kelantan
# 3    41401  Kuala Lumpur
# 4    41415        Labuan

# %%
print(df_state_labels.count())
print(df_state_labels.isnull().values.any())
# Out:
# StateID      15
# StateName    15
# dtype: int64
# False

# %%
df_state_labels.columns
# Out:
# Index(['StateID', 'StateName'], dtype='object')

# %%
# Combine Dataframes
# result = pd.concat([df1, df4], axis=1, join="inner")

# Try to join Breed1 from Train.csv with BreedID from breed_labels.csv

df_train_data = pd.merge(df_train_data, df_breed_labels, on="BreedID", how="left")
df_train_data = pd.merge(df_train_data, df_color_labels, on="ColorID", how="left")
df_train_data = pd.merge(df_train_data, df_state_labels, on="StateID", how="left")

# %%
df_train_data
# Out:
#        Type_x            Name  Age  BreedID  BreedID2  Gender  ColorID  \
# 0           2          Nibble    3      299         0       1        1
# 1           2     No Name Yet    1      265         0       1        1
# 2           1          Brisco    1      307         0       1        2
# 3           1            Miko    4      307         0       2        1
# 4           1          Hunter    1      307         0       1        1
# ...       ...             ...  ...      ...       ...     ...      ...
# 14988       2             NaN    2      266         0       3        1
# 14989       2  Serato & Eddie   60      265       264       3        1
# 14990       2         Monkies    2      265       266       3        5
# 14991       2         Ms Daym    9      266         0       2        4
# 14992       1            Fili    1      307       307       1        2
#
#        ColorID2  ColorID3  MaturitySize  ...  \
# 0             7         0             1  ...
# ...

# %%
df_train_data = df_train_data.rename(columns={"BreedName": "PrimaryBreed", "ColorName": "PrimaryColor"})
df_train_data
# Out:
#        Type_x            Name  Age  BreedID  BreedID2  Gender  ColorID  \
# 0           2          Nibble    3      299         0       1        1
# 1           2     No Name Yet    1      265         0       1        1
# 2           1          Brisco    1      307         0       1        2
# 3           1            Miko    4      307         0       2        1
# 4           1          Hunter    1      307         0       1        1
# ...       ...             ...  ...      ...       ...     ...      ...
# 14988       2             NaN    2      266         0       3        1
# 14989       2  Serato & Eddie   60      265       264       3        1
# 14990       2         Monkies    2      265       266       3        5
# 14991       2         Ms Daym    9      266         0       2        4
# 14992       1            Fili    1      307       307       1        2
#
#        ColorID2  ColorID3  MaturitySize  ...  \
# 0             7         0             1  ...
# ...

# %%
df_country = pd.DataFrame(
    {"StateName": ["Johor", "Kedah", "Kelantan", "Kuala Lumpur", "Labuan", "Melaka", "Negeri Sembilan", "Pahang", "Perak", "Perlis", "Pulau Pinang", "Sabah", "Sarawak", "Selangor", "Terengganu"],
     "Country": ["Malaysia", "Malaysia", "Malaysia", "Malaysia", "Malaysia", "Malaysia","Malaysia", "Malaysia", "Malaysia", "Malaysia", "Malaysia", "Malaysia", "Malaysia", "Malaysia", "Malaysia"]
     })

df_country
# Out:
#           StateName   Country
# 0             Johor  Malaysia
# 1             Kedah  Malaysia
# 2          Kelantan  Malaysia
# 3      Kuala Lumpur  Malaysia
# 4            Labuan  Malaysia
# 5            Melaka  Malaysia
# 6   Negeri Sembilan  Malaysia
# 7            Pahang  Malaysia
# 8             Perak  Malaysia
# 9            Perlis  Malaysia
# 10     Pulau Pinang  Malaysia
# 11            Sabah  Malaysia
# 12          Sarawak  Malaysia
# 13         Selangor  Malaysia
# 14       Terengganu  Malaysia

# %%
df_train_data = pd.merge(df_train_data, df_country, on="StateName", how="left")

# %%
# Gender - Gender of pet (1 = Male, 2 = Female, 3 = Mixed, if profile represents group of pets)
# df['year']=df['year'].astype(int)

df_gender = pd.DataFrame(
    {"Gender": ["1", "2", "3"],
     "GenderofPet": ["Male", "Female", "Mixed"]
     })

df_gender['Gender']= df_gender['Gender'].astype(str)
df_train_data['Gender']= df_train_data['Gender'].astype(str)

# %%
df_train_data = pd.merge(df_train_data, df_gender, on="Gender", how="right")

# %%
df_train_data
# Out:
#        Type_x             Name  Age  BreedID  BreedID2 Gender  ColorID  \
# 0           2           Nibble    3      299         0      1        1
# 1           2      No Name Yet    1      265         0      1        1
# 2           1           Brisco    1      307         0      1        2
# 3           1           Hunter    1      307         0      1        1
# 4           2            BULAT   12      264       264      1        1
# ...       ...              ...  ...      ...       ...    ...      ...
# 14988       2  Sentul Kittiens    2      266         0      3        3
# 14989       2    Cici N Shelly   84      264       264      3        1
# 14990       2              NaN    2      266         0      3        1
# 14991       2   Serato & Eddie   60      265       264      3        1
# 14992       2          Monkies    2      265       266      3        5
#
#        ColorID2  ColorID3  MaturitySize  ...  \
# 0             7         0             1  ...
# ...

# %%
# Export to CSV - Last Export: 03/11/2021 @ 3:26
# df_train_data.to_csv("malaysia_tableau.csv")
